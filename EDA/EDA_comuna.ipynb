# %%
import pandas as pd
import geopandas as gpd

# %%
#Read the file
df_places = gpd.read_file(r'D:\0_Respaldo\0_Proyectos_2024\Henry_Labs\Lab2\Baires_Accidents\Data\comunas.geojson')

# %%
df_places.sample(5)
# Out:
#     ID          OBJETO  COMUNAS  \
# 13  12  LIMITE COMUNAL      8.0
# 11  10  LIMITE COMUNAL      3.0
# 5    9  LIMITE COMUNAL     14.0
# 14  14  LIMITE COMUNAL      1.0
# 10   4  LIMITE COMUNAL      7.0
#
#                                               BARRIOS     PERIMETRO  \
# 13     VILLA LUGANO - VILLA RIACHUELO - VILLA SOLDATI  20935.012513
# 11                          BALVANERA - SAN CRISTOBAL  10486.260809
# 5                                             PALERMO  22126.531858
# 14  CONSTITUCION - MONTSERRAT - PUERTO MADERO - RE...  36102.201573
# 10                          FLORES - PARQUE CHACABUCO  17972.257870
#
#             AREA                                           geometry
# 13  2.221690e+07  MULTIPOLYGON (((-58.46040 -34.65681, -58.46040...
# 11  6.385991e+06  MULTIPOLYGON (((-58.41192 -34.59800, -58.41029...
# 5   1.584587e+07  MULTIPOLYGON (((-58.42676 -34.55202, -58.42676...
# 14  1.779457e+07  MULTIPOLYGON (((-58.36854 -34.57365, -58.36852...
# ...

# %%
import plotly.express as px

# %%
df_places['geometry'][1]
# Out:
# <MULTIPOLYGON (((-58.431 -34.607, -58.431 -34.608, -58.431 -34.608, -58.431 ...>

# %%
df_places.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         15 non-null     int64
#  1   OBJETO     15 non-null     object
#  2   COMUNAS    15 non-null     float64
#  3   BARRIOS    15 non-null     object
#  4   PERIMETRO  15 non-null     float64
#  5   AREA       15 non-null     float64
#  6   geometry   15 non-null     geometry
# dtypes: float64(3), geometry(1), int64(1), object(2)
# memory usage: 972.0+ bytes

# %%
df_places.describe()
# Out:
#               ID    COMUNAS     PERIMETRO          AREA
# count  15.000000  15.000000     15.000000  1.500000e+01
# mean    8.000000   8.000000  20587.190459  1.360458e+07
# std     4.472136   4.472136   7510.793844  5.193868e+06
# min     1.000000   1.000000  10486.260809  6.317265e+06
# 25%     4.500000   4.500000  17532.387476  9.636965e+06
# 50%     8.000000   8.000000  19987.696155  1.432290e+07
# 75%    11.500000  11.500000  21789.685253  1.617559e+07
# max    15.000000  15.000000  36102.201573  2.221690e+07

# %%
df_places.to_parquet(r'D:\0_Respaldo\0_Proyectos_2024\Henry_Labs\Lab2\Baires_Accidents\Data\Parquet\comuna.parquet', index=False)
